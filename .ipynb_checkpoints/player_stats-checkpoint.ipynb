# %%
# Imports
from chessdotcom import *
import pprint
import requests

import urllib.request
import json

import numpy as np
import pandas as pd
import pickle
import json

# %%
## Configure Headers, as the Project uses requests package to interact with the API. Headers and paxis can be set
## through the Client Object.
from chessdotcom import Client

Client.request_config["headers"]["User-Agent"] = (
 "Machine learning for chess match outcome Prediction, BSc in Computer Science Dissertation, University of Lincoln"
 "Contact me at conorjackvincent@live.co.uk"
)

# Implement rate limiting to be applied to any method used within the chessdotcom library.
Client.rate_limit_handler.tries = 2
Client.rate_limit_handler.tts = 4

# %%
## Load the player_profiles_orginal.pkl file, so that we can use this pandas dataframes usernames to collect further statistical data.
with open('Collected_Chess_Data\player_profiles_original.pkl', 'rb') as file:
    player_profiles = pickle.load(file)

# %%
## View the loaded pandas dataframe.
player_profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10204 entries, 0 to 354
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8115 non-null   object
#  1   username      10204 non-null  object
#  2   title         10204 non-null  object
#  3   followers     10204 non-null  int64
#  4   country_code  10204 non-null  object
#  5   country       10204 non-null  object
#  6   status        10204 non-null  object
#  7   is_streamer   10204 non-null  bool
#  8   verified      10204 non-null  bool
#  9   league        8474 non-null   object
# dtypes: bool(2), int64(1), object(7)
# memory usage: 737.4+ KB

# %%
# Create a list of all the usernames from the player_profiles pandas dataframe.
usernames = player_profiles['username'].tolist()

# %%
def player_stat_dict(username_list):
    """
    Retrieves player statistics from Chess.com API for a list of usernames and returns a dictionary of statistics.

    Parameters:
        username_list (list): A list of usernames for which player statistics are to be retrieved.

    Returns:
        dict: A dictionary where keys are usernames and values are dictionaries containing player statistics.
        list: A list of usernames for which retrieval of statistics failed after maximum retries.

    This function iterates through the provided list of usernames, retrieving player statistics from the Chess.com API 
    using the `get_player_stats` function. It flattens the JSON response structure and stores the statistics in a dictionary 
    with usernames as keys. If an error occurs during retrieval, it retries up to 15 times before moving on to the next username. 
    Failed usernames are appended to the fail_list. The function returns the dictionary of player statistics and the list 
    of failed usernames separately.
    """
    stat_dict = {} # Dictionary to store player statistics.
    fail_list = [] # List to store usernames for which retrieval failed.
    
    counter = 0 # Counter for displaying progress.
    retry = 0 # Counter for retry attempts.
    
    for username in username_list:
        while True:
            try:
                # Retrieve player statistics for the current username.
                player_profile_stat_response = get_player_stats(username)
                json_structure = player_profile_stat_response.json

                # Flatten the JSON structure and convert to a dictionary.
                flatten_json_structure = pd.json_normalize(json_structure, sep='_').to_dict(orient='records')[0]

                # Print the counter, overwriting the previous counter.
                counter+=1
                print(f'\r{counter} {username}', end='', flush=True)

                # Store the player statistics in the stat_dict.
                stat_dict[username] = flatten_json_structure

                break
            
            except ChessDotComError as e:
                # Handle the ChessDotComError and retry
                print(f'\rError for {username}: {e}')
                if retry < 15:
                    retry += 1
                    print(f'\rRetrying for {username} attempt {retry}...')
                    
                # If max retries reached, move on to the next username
                else:
                    print(f'\rMax retries reached for {username}. Moving on.')
                    fail_list.append(username)
                    retry = 0
                    break

    return stat_dict, fail_list

# %%
# Call the player_stat_dict with usernames list as argument.
player_statistics, fail_list = player_stat_dict(usernames)
# Out:
# 10204 zauraabdullamarieat2r16r

# %%
print(fail_list)
# Out:
# []

# %%
# Visually inspect a random usernames statistics.
print(player_statistics[usernames[3]])
print(len(player_statistics))
# Out:
# {'stats_chess_rapid_last_rating': 1616, 'stats_chess_rapid_last_date': 1685650311, 'stats_chess_rapid_last_rd': 346, 'stats_chess_rapid_best_rating': 2300, 'stats_chess_rapid_best_date': 1604208940, 'stats_chess_rapid_best_game': 'https://www.chess.com/game/live/71067866733', 'stats_chess_rapid_record_win': 6, 'stats_chess_rapid_record_loss': 1, 'stats_chess_rapid_record_draw': 0, 'stats_chess_bullet_last_rating': 2246, 'stats_chess_bullet_last_date': 1706713719, 'stats_chess_bullet_last_rd': 59, 'stats_chess_bullet_best_rating': 2344, 'stats_chess_bullet_best_date': 1585682431, 'stats_chess_bullet_best_game': 'https://www.chess.com/game/live/5045949960', 'stats_chess_bullet_record_win': 1232, 'stats_chess_bullet_record_loss': 1188, 'stats_chess_bullet_record_draw': 96, 'stats_chess_blitz_last_rating': 2409, 'stats_chess_blitz_last_date': 1708541304, 'stats_chess_blitz_last_rd': 24, 'stats_chess_blitz_best_rating': 2603, 'stats_chess_blitz_best_date': 1707221490, 'stats_chess_blitz_best_game': 'https://www.chess.com/game/live/29413215163', 'stats_chess_blitz_record_win': 4179, 'stats_chess_blitz_record_loss': 4255, 'stats_chess_blitz_record_draw': 665, 'stats_tactics_highest_rating': 2127, 'stats_tactics_highest_date': 1707566703, 'stats_tactics_lowest_rating': 400, 'stats_tactics_lowest_date': 1642341903, 'stats_puzzle_rush_best_total_attempts': 48, 'stats_puzzle_rush_best_score': 45, 'stats_puzzle_rush_daily_total_attempts': 29, 'stats_puzzle_rush_daily_score': 28}
# 10204

# %%
def player_stat_dict_to_df(dict):
    """
    Converts player statistics dictionary into separate lists of dictionaries for different game categories.

    Parameters:
        stat_dict (dict): A dictionary containing player statistics.

    Returns:
        list: List of dictionaries for daily chess statistics.
        list: List of dictionaries for Chess960 (Fischer Random Chess) statistics.
        list: List of dictionaries for rapid chess statistics.
        list: List of dictionaries for bullet chess statistics.
        list: List of dictionaries for blitz chess statistics.
        list: List of dictionaries for FIDE (International Chess Federation) rating statistics.
        list: List of dictionaries for tactics training statistics.
        list: List of dictionaries for Puzzle Rush statistics.

    This function takes a dictionary containing player statistics and transforms it into separate lists of dictionaries, 
    each representing a different game category. The function iterates through the input dictionary and extracts relevant 
    statistics for each game category, such as daily chess, chess960, rapid, bullet, blitz, FIDE, tactics, and puzzle rush. 
    Each dictionary in the resulting lists contains the username and statistics specific to the corresponding game category.

    The function returns multiple lists of dictionaries, each containing statistics for a specific game category.
    """
    chess_daily_data = []
    chess960_daily_data = []
    chess_rapid_data = []
    chess_bullet_data = []
    chess_blitz_data = []
    fide_data = []
    tactics_data = []
    puzzle_rush_data = []

    # Iterate through the player statistics dictionary.
    for k, v in dict.items():

        # Initialise Dictionaries for different game categories for the current username.
        chess_daily_dict = {}
        chess960_daily_dict = {}
        chess_rapid_dict = {}
        chess_bullet_dict = {}
        chess_blitz_dict = {}
        fide_dict = {}
        tactics_dict = {}
        puzzle_rush_dict = {}
        
        chess_daily_dict = {'username': k}
        chess960_daily_dict = {'username': k}
        chess_rapid_dict = {'username': k}
        chess_bullet_dict = {'username': k}
        chess_blitz_dict = {'username': k}
        fide_dict = {'username': k}
        tactics_dict = {'username': k}
        puzzle_rush_dict = {'username': k}
    
        # Extract relevant statistics for different game categories.
        for sub_k, sub_b in v.items():
            
            if 'chess_daily' in sub_k:
                key = sub_k.replace('stats_', '')
                chess_daily_dict[key] = sub_b
                
            elif 'chess960_daily' in sub_k:
                key = sub_k.replace('stats_', '')
                chess960_daily_dict[key] = sub_b

            elif 'chess_rapid' in sub_k:
                key = sub_k.replace('stats_', '')
                chess_rapid_dict[key] = sub_b

            elif 'chess_bullet' in sub_k:
                key = sub_k.replace('stats_', '')
                chess_bullet_dict[key] = sub_b

            elif 'chess_blitz' in sub_k:
                key = sub_k.replace('stats_', '')
                chess_blitz_dict[key] = sub_b

            elif 'fide' in sub_k:
                key = sub_k.replace('stats_', '')
                fide_dict[key] = sub_b

            elif 'tactics' in sub_k:
                key = sub_k.replace('stats_', '')
                tactics_dict[key] = sub_b

            elif 'puzzle_rush' in sub_k:
                key = sub_k.replace('stats_', '')
                puzzle_rush_dict[key] = sub_b

        # Append dictionarie sto corresponding lists.
        chess_daily_data.append(chess_daily_dict)
        chess960_daily_data.append(chess960_daily_dict)
        chess_rapid_data.append(chess_rapid_dict)
        chess_bullet_data.append(chess_bullet_dict)
        chess_blitz_data.append(chess_blitz_dict)
        fide_data.append(fide_dict)
        tactics_data.append(tactics_dict)
        puzzle_rush_data.append(puzzle_rush_dict)

    # Return lists of dictionaries for different game categories.
    return chess_daily_data, chess960_daily_data, chess_rapid_data, chess_bullet_data, chess_blitz_data, fide_data, tactics_data, puzzle_rush_data

# %%
# Call the player_stat_dict_to_df and store the lists of dictionaries into variables.
chess_daily_data, chess960_daily_data, chess_rapid_data, chess_bullet_data, chess_blitz_data, fide_data, tactics_data, puzzle_rush_data = player_stat_dict_to_df(player_statistics)

# Display the second element of the fide_data list to check its contents.
print(fide_data[1])
# Out:
# {'username': 'ahachess', 'fide': 0}

# %%
# Convert all the lists of dictionaries into pandas dataframes

df_chess_daily = pd.DataFrame.from_records(chess_daily_data)
df_chess960_daily_data = pd.DataFrame.from_records(chess960_daily_data)
df_chess_rapid_data = pd.DataFrame.from_records(chess_rapid_data)
df_chess_bullet_data = pd.DataFrame.from_records(chess_bullet_data)
df_chess_blitz_data = pd.DataFrame.from_records(chess_blitz_data)
df_fide_data = pd.DataFrame.from_records(fide_data)
df_tactics_data = pd.DataFrame.from_records(tactics_data)
df_puzzle_rush_data = pd.DataFrame.from_records(puzzle_rush_data)

# %%
display(df_chess_daily.head())
display(df_chess_daily.count())
# Out:
#           username  chess_daily_last_rating  chess_daily_last_date  \
# 0  adriananikolova                   1597.0           1.707905e+09
# 1         ahachess                    991.0           1.622643e+09
# 2       ahappypawn                   2000.0           1.690387e+09
# 3         alexa797                      NaN                    NaN
# 4      alyonka0506                      NaN                    NaN
#
#    chess_daily_last_rd  chess_daily_best_rating  chess_daily_best_date  \
# 0                 62.0                   2061.0           1.467041e+09
# 1                216.0                   1200.0           1.308028e+09
# 2                273.0                   2000.0           1.396550e+09
# 3                  NaN                      NaN                    NaN
# 4                  NaN                      NaN                    NaN
#
#                         chess_daily_best_game  chess_daily_record_win  \
# 0  https://www.chess.com/game/daily/122706640                   333.0
# 1  https://www.chess.com/game/daily/194095878                     3.0
# 2   https://www.chess.com/game/daily/85534340                     1.0
# 3                                         NaN                     NaN
# 4                                         NaN                     NaN
#
#    chess_daily_record_loss  chess_daily_record_draw  \
# 0                    132.0                     56.0
# 1                      0.0                      0.0
# 2                      0.0                      0.0
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#    chess_daily_record_time_per_move  chess_daily_record_timeout_percent  \
# 0                           67098.0                                10.0
# 1                           48738.0                                 0.0
# 2                           75501.0                                 0.0
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    chess_daily_tournament_points  chess_daily_tournament_withdraw  \
# 0                            0.0                              1.0
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
#
#    chess_daily_tournament_count  chess_daily_tournament_highest_finish
# 0                           1.0                                    1.0
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
# username                                 10204
# chess_daily_last_rating                   4212
# chess_daily_last_date                     4212
# chess_daily_last_rd                       4212
# chess_daily_best_rating                   3459
# chess_daily_best_date                     3459
# chess_daily_best_game                     3459
# chess_daily_record_win                    4212
# chess_daily_record_loss                   4212
# chess_daily_record_draw                   4212
# chess_daily_record_time_per_move          4212
# chess_daily_record_timeout_percent        4212
# chess_daily_tournament_points              128
# chess_daily_tournament_withdraw            128
# chess_daily_tournament_count               128
# chess_daily_tournament_highest_finish      128
# dtype: int64

# %%
from chessdotcom import Client

Client.request_config["headers"]["User-Agent"] = (
 "Machine learning for chess match outcome Prediction"
 "Contact me at conorjackvincent@live.co.uk"
)

# %%
display(df_chess960_daily_data.head())
display(df_chess960_daily_data.count())
# Out:
#           username  chess960_daily_last_rating  chess960_daily_last_date  \
# 0  adriananikolova                      1566.0              1.494344e+09
# 1         ahachess                         NaN                       NaN
# 2       ahappypawn                         NaN                       NaN
# 3         alexa797                         NaN                       NaN
# 4      alyonka0506                         NaN                       NaN
#
#    chess960_daily_last_rd  chess960_daily_best_rating  \
# 0                   114.0                      1602.0
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
#
#    chess960_daily_best_date                    chess960_daily_best_game  \
# 0              1.481791e+09  https://www.chess.com/game/daily/122097146
# 1                       NaN                                         NaN
# 2                       NaN                                         NaN
# 3                       NaN                                         NaN
# 4                       NaN                                         NaN
#
#    chess960_daily_record_win  chess960_daily_record_loss  \
# 0                       14.0                        10.0
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    chess960_daily_record_draw  chess960_daily_record_time_per_move  \
# 0                         1.0                              67098.0
# 1                         NaN                                  NaN
# 2                         NaN                                  NaN
# 3                         NaN                                  NaN
# 4                         NaN                                  NaN
#
#    chess960_daily_record_timeout_percent  chess960_daily_tournament_points  \
# 0                                   10.0                               0.0
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
#
#    chess960_daily_tournament_withdraw  chess960_daily_tournament_count  \
# 0                                 1.0                              1.0
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
#
#    chess960_daily_tournament_highest_finish
# 0                                       1.0
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# username                                    10204
# chess960_daily_last_rating                    914
# chess960_daily_last_date                      914
# chess960_daily_last_rd                        914
# chess960_daily_best_rating                    764
# chess960_daily_best_date                      764
# chess960_daily_best_game                      764
# chess960_daily_record_win                     914
# chess960_daily_record_loss                    914
# chess960_daily_record_draw                    914
# chess960_daily_record_time_per_move           914
# chess960_daily_record_timeout_percent         914
# chess960_daily_tournament_points               57
# chess960_daily_tournament_withdraw             57
# chess960_daily_tournament_count                57
# chess960_daily_tournament_highest_finish       57
# dtype: int64

# %%
display(df_chess_rapid_data.head())
display(df_chess_rapid_data.count())
# Out:
#           username  chess_rapid_last_rating  chess_rapid_last_date  \
# 0  adriananikolova                   2187.0           1.707994e+09
# 1         ahachess                      NaN                    NaN
# 2       ahappypawn                   2049.0           1.678995e+09
# 3         alexa797                   1616.0           1.685650e+09
# 4      alyonka0506                   2112.0           1.688465e+09
#
#    chess_rapid_last_rd  chess_rapid_best_rating  chess_rapid_best_date  \
# 0                116.0                   2363.0           1.482703e+09
# 1                  NaN                      NaN                    NaN
# 2                127.0                   2369.0           1.417989e+09
# 3                346.0                   2300.0           1.604209e+09
# 4                225.0                   1479.0           1.610890e+09
#
#                          chess_rapid_best_game  chess_rapid_record_win  \
# 0  https://www.chess.com/game/live/58465801167                   377.0
# 1                                          NaN                     NaN
# 2   https://www.chess.com/game/live/4997404622                    22.0
# 3  https://www.chess.com/game/live/71067866733                     6.0
# 4   https://www.chess.com/game/live/6261905959                     2.0
#
#    chess_rapid_record_loss  chess_rapid_record_draw
# 0                     59.0                     34.0
# 1                      NaN                      NaN
# 2                     25.0                     14.0
# 3                      1.0                      0.0
# 4                      0.0                      0.0
# username                   10204
# chess_rapid_last_rating     7757
# chess_rapid_last_date       7757
# chess_rapid_last_rd         7756
# chess_rapid_best_rating     7440
# chess_rapid_best_date       7440
# chess_rapid_best_game       7440
# chess_rapid_record_win      7757
# chess_rapid_record_loss     7757
# chess_rapid_record_draw     7757
# dtype: int64

# %%
display(df_chess_bullet_data.head())
display(df_chess_bullet_data.count())
# Out:
#           username  chess_bullet_last_rating  chess_bullet_last_date  \
# 0  adriananikolova                    2569.0            1.708297e+09
# 1         ahachess                    2180.0            1.629462e+09
# 2       ahappypawn                    2482.0            1.691534e+09
# 3         alexa797                    2246.0            1.706714e+09
# 4      alyonka0506                       NaN                     NaN
#
#    chess_bullet_last_rd  chess_bullet_best_rating  chess_bullet_best_date  \
# 0                  34.0                    2704.0            1.653683e+09
# 1                  77.0                    2493.0            1.534284e+09
# 2                  87.0                    2618.0            1.613972e+09
# 3                  59.0                    2344.0            1.585682e+09
# 4                   NaN                       NaN                     NaN
#
#                         chess_bullet_best_game  chess_bullet_record_win  \
# 0  https://www.chess.com/game/live/68673769853                   5257.0
# 1   https://www.chess.com/game/live/3006554673                    415.0
# 2   https://www.chess.com/game/live/3420144449                    363.0
# 3   https://www.chess.com/game/live/5045949960                   1232.0
# 4                                          NaN                      NaN
#
#    chess_bullet_record_loss  chess_bullet_record_draw
# 0                    6047.0                     852.0
# 1                     293.0                      29.0
# 2                     488.0                      36.0
# 3                    1188.0                      96.0
# 4                       NaN                       NaN
# username                    10204
# chess_bullet_last_rating     8454
# chess_bullet_last_date       8454
# chess_bullet_last_rd         8454
# chess_bullet_best_rating     8206
# chess_bullet_best_date       8206
# chess_bullet_best_game       8206
# chess_bullet_record_win      8454
# chess_bullet_record_loss     8454
# chess_bullet_record_draw     8454
# dtype: int64

# %%
display(df_chess_blitz_data.head())
display(df_chess_blitz_data.count())
# Out:
#           username  chess_blitz_last_rating  chess_blitz_last_date  \
# 0  adriananikolova                   2406.0           1.708297e+09
# 1         ahachess                   2247.0           1.639848e+09
# 2       ahappypawn                   2459.0           1.693020e+09
# 3         alexa797                   2409.0           1.708541e+09
# 4      alyonka0506                   2161.0           1.686768e+09
#
#    chess_blitz_last_rd  chess_blitz_best_rating  chess_blitz_best_date  \
# 0                 34.0                   2563.0           1.658590e+09
# 1                 55.0                   2424.0           1.534111e+09
# 2                 34.0                   2595.0           1.622733e+09
# 3                 24.0                   2603.0           1.707221e+09
# 4                158.0                   2269.0           1.686764e+09
#
#                          chess_blitz_best_game  chess_blitz_record_win  \
# 0  https://www.chess.com/game/live/67197246713                  3876.0
# 1   https://www.chess.com/game/live/4726301080                   281.0
# 2   https://www.chess.com/game/live/5037423524                   501.0
# 3  https://www.chess.com/game/live/29413215163                  4179.0
# 4  https://www.chess.com/game/live/80505802063                     6.0
#
#    chess_blitz_record_loss  chess_blitz_record_draw
# 0                   3442.0                    604.0
# 1                    237.0                     53.0
# 2                    550.0                     58.0
# 3                   4255.0                    665.0
# 4                      4.0                      1.0
# username                   10204
# chess_blitz_last_rating     9856
# chess_blitz_last_date       9856
# chess_blitz_last_rd         9856
# chess_blitz_best_rating     9817
# chess_blitz_best_date       9817
# chess_blitz_best_game       9817
# chess_blitz_record_win      9856
# chess_blitz_record_loss     9856
# chess_blitz_record_draw     9856
# dtype: int64

# %%
display(df_fide_data.head())
display(df_fide_data.count())
# Out:
#           username    fide
# 0  adriananikolova  2389.0
# 1         ahachess     0.0
# 2       ahappypawn     0.0
# 3         alexa797     NaN
# 4      alyonka0506     NaN
# username    10204
# fide         5628
# dtype: int64

# %%
display(df_tactics_data.head())
display(df_tactics_data.count())
# Out:
#           username  tactics_highest_rating  tactics_highest_date  \
# 0  adriananikolova                    3511            1706825516
# 1         ahachess                    2796            1660022336
# 2       ahappypawn                    4280            1552687112
# 3         alexa797                    2127            1707566703
# 4      alyonka0506                    1254            1661869276
#
#    tactics_lowest_rating  tactics_lowest_date
# 0                   1361           1445695301
# 1                   1372           1308145044
# 2                   1356           1329704746
# 3                    400           1642341903
# 4                    411           1512244187
# username                  10204
# tactics_highest_rating    10204
# tactics_highest_date      10204
# tactics_lowest_rating     10204
# tactics_lowest_date       10204
# dtype: int64

# %%
display(df_puzzle_rush_data.head())
display(df_puzzle_rush_data.count())
# Out:
#           username  puzzle_rush_best_total_attempts  puzzle_rush_best_score  \
# 0  adriananikolova                             80.0                    77.0
# 1         ahachess                             43.0                    40.0
# 2       ahappypawn                             71.0                    68.0
# 3         alexa797                             48.0                    45.0
# 4      alyonka0506                             55.0                    52.0
#
#    puzzle_rush_daily_total_attempts  puzzle_rush_daily_score
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                              29.0                     28.0
# 4                              39.0                     36.0
# username                            10204
# puzzle_rush_best_total_attempts      8180
# puzzle_rush_best_score               8180
# puzzle_rush_daily_total_attempts      441
# puzzle_rush_daily_score               441
# dtype: int64

# %%
with open('Collected_Chess_Data\chess_daily.pkl', 'wb') as file:
    pickle.dump(df_chess_daily, file)

with open('Collected_Chess_Data\chess960_daily.pkl', 'wb') as file:
    pickle.dump(df_chess960_daily_data, file)

with open('Collected_Chess_Data\chess_rapid.pkl', 'wb') as file:
    pickle.dump(df_chess_rapid_data, file)

with open('Collected_Chess_Data\chess_bullet.pkl', 'wb') as file:
    pickle.dump(df_chess_bullet_data, file)

with open('Collected_Chess_Data\chess_blitz.pkl', 'wb') as file:
    pickle.dump(df_chess_blitz_data, file)

with open('Collected_Chess_Data\fide.pkl', 'wb') as file:
    pickle.dump(df_fide_data, file)

with open('Collected_Chess_Data\tactics.pkl', 'wb') as file:
    pickle.dump(df_tactics_data, file)

with open('Collected_Chess_Data\puzzle_rush.pkl', 'wb') as file:
    pickle.dump(df_puzzle_rush_data, file)

# %%
merged_df = pd.merge(player_profiles, df_chess_daily, on='username', how='outer')
merged_df = pd.merge(merged_df, df_chess960_daily_data, on='username', how='outer')
merged_df = pd.merge(merged_df, df_chess_rapid_data, on='username', how='outer')
merged_df = pd.merge(merged_df, df_chess_bullet_data, on='username', how='outer')
merged_df = pd.merge(merged_df, df_chess_blitz_data, on='username', how='outer')
merged_df = pd.merge(merged_df, df_fide_data, on='username', how='outer')
merged_df = pd.merge(merged_df, df_tactics_data, on='username', how='outer')
merged_df = pd.merge(merged_df, df_puzzle_rush_data, on='username', how='outer')

merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10204 entries, 0 to 10203
# Data columns (total 76 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   name                                      8115 non-null   object
#  1   username                                  10204 non-null  object
#  2   title                                     10204 non-null  object
#  3   followers                                 10204 non-null  int64
#  4   country_code                              10204 non-null  object
#  5   country                                   10204 non-null  object
#  6   status                                    10204 non-null  object
#  7   is_streamer                               10204 non-null  bool
#  8   verified                                  10204 non-null  bool
#  9   league                                    8474 non-null   object
#  10  chess_daily_last_rating                   4212 non-null   float64
#  11  chess_daily_last_date                     4212 non-null   float64
#  12  chess_daily_last_rd                       4212 non-null   float64
#  13  chess_daily_best_rating                   3459 non-null   float64
#  14  chess_daily_best_date                     3459 non-null   float64
#  15  chess_daily_best_game                     3459 non-null   object
#  16  chess_daily_record_win                    4212 non-null   float64
#  17  chess_daily_record_loss                   4212 non-null   float64
#  18  chess_daily_record_draw                   4212 non-null   float64
#  19  chess_daily_record_time_per_move          4212 non-null   float64
#  20  chess_daily_record_timeout_percent        4212 non-null   float64
#  21  chess_daily_tournament_points             128 non-null    float64
#  22  chess_daily_tournament_withdraw           128 non-null    float64
#  23  chess_daily_tournament_count              128 non-null    float64
#  24  chess_daily_tournament_highest_finish     128 non-null    float64
#  25  chess960_daily_last_rating                914 non-null    float64
#  26  chess960_daily_last_date                  914 non-null    float64
#  27  chess960_daily_last_rd                    914 non-null    float64
#  28  chess960_daily_best_rating                764 non-null    float64
#  29  chess960_daily_best_date                  764 non-null    float64
#  30  chess960_daily_best_game                  764 non-null    object
#  31  chess960_daily_record_win                 914 non-null    float64
#  32  chess960_daily_record_loss                914 non-null    float64
#  33  chess960_daily_record_draw                914 non-null    float64
#  34  chess960_daily_record_time_per_move       914 non-null    float64
#  35  chess960_daily_record_timeout_percent     914 non-null    float64
#  36  chess960_daily_tournament_points          57 non-null     float64
#  37  chess960_daily_tournament_withdraw        57 non-null     float64
#  38  chess960_daily_tournament_count           57 non-null     float64
#  39  chess960_daily_tournament_highest_finish  57 non-null     float64
#  40  chess_rapid_last_rating                   7757 non-null   float64
#  41  chess_rapid_last_date                     7757 non-null   float64
#  42  chess_rapid_last_rd                       7756 non-null   float64
#  43  chess_rapid_best_rating                   7440 non-null   float64
#  44  chess_rapid_best_date                     7440 non-null   float64
#  45  chess_rapid_best_game                     7440 non-null   object
#  46  chess_rapid_record_win                    7757 non-null   float64
#  47  chess_rapid_record_loss                   7757 non-null   float64
#  48  chess_rapid_record_draw                   7757 non-null   float64
#  49  chess_bullet_last_rating                  8454 non-null   float64
#  50  chess_bullet_last_date                    8454 non-null   float64
#  51  chess_bullet_last_rd                      8454 non-null   float64
#  52  chess_bullet_best_rating                  8206 non-null   float64
#  53  chess_bullet_best_date                    8206 non-null   float64
#  54  chess_bullet_best_game                    8206 non-null   object
#  55  chess_bullet_record_win                   8454 non-null   float64
#  56  chess_bullet_record_loss                  8454 non-null   float64
#  57  chess_bullet_record_draw                  8454 non-null   float64
#  58  chess_blitz_last_rating                   9856 non-null   float64
#  59  chess_blitz_last_date                     9856 non-null   float64
#  60  chess_blitz_last_rd                       9856 non-null   float64
#  61  chess_blitz_best_rating                   9817 non-null   float64
#  62  chess_blitz_best_date                     9817 non-null   float64
#  63  chess_blitz_best_game                     9817 non-null   object
#  64  chess_blitz_record_win                    9856 non-null   float64
#  65  chess_blitz_record_loss                   9856 non-null   float64
#  66  chess_blitz_record_draw                   9856 non-null   float64
#  67  fide                                      5628 non-null   float64
#  68  tactics_highest_rating                    10204 non-null  int64
#  69  tactics_highest_date                      10204 non-null  int64
#  70  tactics_lowest_rating                     10204 non-null  int64
#  71  tactics_lowest_date                       10204 non-null  int64
#  72  puzzle_rush_best_total_attempts           8180 non-null   float64
#  73  puzzle_rush_best_score                    8180 non-null   float64
#  74  puzzle_rush_daily_total_attempts          441 non-null    float64
#  75  puzzle_rush_daily_score                   441 non-null    float64
# dtypes: bool(2), float64(57), int64(5), object(12)
# memory usage: 5.8+ MB
